# %%
import pandas as pd
import os
import xarray as xr

# %% [markdown]
# ## Data Reading

# %%
df_mapping = pd.read_csv("../../data/processed/mapping/no2_to_traffic_sensor_mapping.csv")

df_air = pd.read_parquet("../../data/processed/air/df_air_quality_and_locations_from_2013.parquet")

# %% [markdown]
# Read traffic data

# %%
# Define the root directory for processed traffic data
root_dir = '../../data/processed/traffic'

# List to hold DataFrames
dataframes = []

# Iterate through all folders in the root directory
for folder_name in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder_name)
    
    # Check if the folder exists and is a directory
    if os.path.isdir(folder_path):
        print(f"Processing folder: {folder_path}")
        
        # Iterate through all files in the folder
        for file_name in os.listdir(folder_path):
            if file_name.endswith('.parquet'):  # Ensure it's a Parquet file
                file_path = os.path.join(folder_path, file_name)
                
                # Read the Parquet file
                try:
                    df = pd.read_parquet(file_path)
                    print(f"Successfully read: {file_path} with {len(df)} rows.")
                    
                    # Append the DataFrame to the list
                    dataframes.append(df)
                    
                except Exception as e:
                    print(f"Error reading file {file_name}: {e}")

# Concatenate all DataFrames into one
if dataframes:  # Check if the list is not empty
    df_traffic = pd.concat(dataframes, ignore_index=True)
    print(f"Combined DataFrame created with {len(df_traffic)} rows.")
# Out:
# Processing folder: ../../data/processed/traffic/2022
# Successfully read: ../../data/processed/traffic/2022/12-2022_processed.parquet with 48331 rows.
# Successfully read: ../../data/processed/traffic/2022/11-2022_processed.parquet with 46722 rows.
# Successfully read: ../../data/processed/traffic/2022/10-2022_processed.parquet with 47576 rows.
# Successfully read: ../../data/processed/traffic/2022/01-2022_processed.parquet with 45047 rows.
# Successfully read: ../../data/processed/traffic/2022/06-2022_processed.parquet with 42196 rows.
# Successfully read: ../../data/processed/traffic/2022/05-2022_processed.parquet with 42735 rows.
# Successfully read: ../../data/processed/traffic/2022/08-2022_processed.parquet with 45087 rows.
# Successfully read: ../../data/processed/traffic/2022/02-2022_processed.parquet with 40460 rows.
# Successfully read: ../../data/processed/traffic/2022/03-2022_processed.parquet with 44372 rows.
# Successfully read: ../../data/processed/traffic/2022/09-2022_processed.parquet with 46207 rows.
# Successfully read: ../../data/processed/traffic/2022/04-2022_processed.parquet with 42616 rows.
# Successfully read: ../../data/processed/traffic/2022/07-2022_processed.parquet with 44018 rows.
# Processing folder: ../../data/processed/traffic/2024
# Successfully read: ../../data/processed/traffic/2024/10-2024_processed.parquet with 45475 rows.
# Successfully read: ../../data/processed/traffic/2024/09_2024_processed.parquet with 44131 rows.
# Successfully read: ../../data/processed/traffic/2024/11-2024_processed.parquet with 43539 rows.
# Successfully read: ../../data/processed/traffic/2024/12-2024_processed.parquet with 44869 rows.
# Successfully read: ../../data/processed/traffic/2024/07-2024_processed.parquet with 46142 rows.
# Successfully read: ../../data/processed/traffic/2024/04-2024_processed.parquet with 46185 rows.
# Successfully read: ../../data/processed/traffic/2024/03-2024_processed.parquet with 47787 rows.
# Successfully read: ../../data/processed/traffic/2024/08-2024_processed.parquet with 46974 rows.
# Successfully read: ../../data/processed/traffic/2024/02-2024_processed.parquet with 44676 rows.
# Successfully read: ../../data/processed/traffic/2024/05-2024_processed.parquet with 46887 rows.
# Successfully read: ../../data/processed/traffic/2024/06-2024_processed.parquet with 45093 rows.
# Successfully read: ../../data/processed/traffic/2024/01-2024_processed.parquet with 48040 rows.
# Processing folder: ../../data/processed/traffic/2023
# Successfully read: ../../data/processed/traffic/2023/11-2023_processed.parquet with 45523 rows.
# Successfully read: ../../data/processed/traffic/2023/12-2023_processed.parquet with 47876 rows.
# Successfully read: ../../data/processed/traffic/2023/10-2023_processed.parquet with 45348 rows.
# Successfully read: ../../data/processed/traffic/2023/05-2023_processed.parquet with 47733 rows.
# Successfully read: ../../data/processed/traffic/2023/08-2023_processed.parquet with 45418 rows.
# Successfully read: ../../data/processed/traffic/2023/02-2023_processed.parquet with 43412 rows.
# Successfully read: ../../data/processed/traffic/2023/01-2023_processed.parquet with 48273 rows.
# Successfully read: ../../data/processed/traffic/2023/06-2023_processed.parquet with 45088 rows.
# Successfully read: ../../data/processed/traffic/2023/07-2023_processed.parquet with 45591 rows.
# Successfully read: ../../data/processed/traffic/2023/03-2023_processed.parquet with 48112 rows.
# Successfully read: ../../data/processed/traffic/2023/09-2023_processed.parquet with 44461 rows.
# Successfully read: ../../data/processed/traffic/2023/04-2023_processed.parquet with 46202 rows.
# Processing folder: ../../data/processed/traffic/2019
# Successfully read: ../../data/processed/traffic/2019/01-2019_processed.parquet with 39596 rows.
# Successfully read: ../../data/processed/traffic/2019/06-2019_processed.parquet with 36510 rows.
# Successfully read: ../../data/processed/traffic/2019/05-2019_processed.parquet with 36285 rows.
# Successfully read: ../../data/processed/traffic/2019/02-2019_processed.parquet with 34803 rows.
# Successfully read: ../../data/processed/traffic/2019/08-2019_processed.parquet with 37917 rows.
# Successfully read: ../../data/processed/traffic/2019/09-2019_processed.parquet with 36701 rows.
# Successfully read: ../../data/processed/traffic/2019/03-2019_processed.parquet with 36931 rows.
# Successfully read: ../../data/processed/traffic/2019/04-2019_processed.parquet with 34407 rows.
# Successfully read: ../../data/processed/traffic/2019/07-2019_processed.parquet with 38182 rows.
# Successfully read: ../../data/processed/traffic/2019/12-2019_processed.parquet with 38639 rows.
# Successfully read: ../../data/processed/traffic/2019/11-2019_processed.parquet with 38137 rows.
# Successfully read: ../../data/processed/traffic/2019/10-2019_processed.parquet with 39175 rows.
# Processing folder: ../../data/processed/traffic/2021
# Successfully read: ../../data/processed/traffic/2021/10-2021_processed.parquet with 41419 rows.
# Successfully read: ../../data/processed/traffic/2021/11-2021_processed.parquet with 40748 rows.
# Successfully read: ../../data/processed/traffic/2021/12-2021_processed.parquet with 45004 rows.
# Successfully read: ../../data/processed/traffic/2021/07-2021_processed.parquet with 39032 rows.
# Successfully read: ../../data/processed/traffic/2021/03-2021_processed.parquet with 36675 rows.
# Successfully read: ../../data/processed/traffic/2021/09-2021_processed.parquet with 38297 rows.
# Successfully read: ../../data/processed/traffic/2021/04-2021_processed.parquet with 35328 rows.
# Successfully read: ../../data/processed/traffic/2021/05-2021_processed.parquet with 37858 rows.
# Successfully read: ../../data/processed/traffic/2021/08-2021_processed.parquet with 39345 rows.
# Successfully read: ../../data/processed/traffic/2021/02-2021_processed.parquet with 33489 rows.
# Successfully read: ../../data/processed/traffic/2021/01-2021_processed.parquet with 34287 rows.
# Successfully read: ../../data/processed/traffic/2021/06-2021_processed.parquet with 35442 rows.
# Processing folder: ../../data/processed/traffic/2020
# Successfully read: ../../data/processed/traffic/2020/10-2020_processed.parquet with 37146 rows.
# Successfully read: ../../data/processed/traffic/2020/12-2020_processed.parquet with 36801 rows.
# Successfully read: ../../data/processed/traffic/2020/11-2020_processed.parquet with 36843 rows.
# Successfully read: ../../data/processed/traffic/2020/03-2020_processed.parquet with 37283 rows.
# Successfully read: ../../data/processed/traffic/2020/09-2020_processed.parquet with 35380 rows.
# Successfully read: ../../data/processed/traffic/2020/04-2020_processed.parquet with 35347 rows.
# Successfully read: ../../data/processed/traffic/2020/07-2020_processed.parquet with 37325 rows.
# Successfully read: ../../data/processed/traffic/2020/01-2020_processed.parquet with 37937 rows.
# Successfully read: ../../data/processed/traffic/2020/06-2020_processed.parquet with 35622 rows.
# Successfully read: ../../data/processed/traffic/2020/05-2020_processed.parquet with 35734 rows.
# Successfully read: ../../data/processed/traffic/2020/08-2020_processed.parquet with 36788 rows.
# Successfully read: ../../data/processed/traffic/2020/02-2020_processed.parquet with 35706 rows.
# Processing folder: ../../data/processed/traffic/2018
# Successfully read: ../../data/processed/traffic/2018/05-2018_processed.parquet with 39368 rows.
# Successfully read: ../../data/processed/traffic/2018/02-2018_processed.parquet with 36471 rows.
# Successfully read: ../../data/processed/traffic/2018/08-2018_processed.parquet with 40184 rows.
# Successfully read: ../../data/processed/traffic/2018/01-2018_processed.parquet with 39973 rows.
# Successfully read: ../../data/processed/traffic/2018/06-2018_processed.parquet with 38895 rows.
# Successfully read: ../../data/processed/traffic/2018/07-2018_processed.parquet with 40112 rows.
# Successfully read: ../../data/processed/traffic/2018/09-2018_processed.parquet with 35822 rows.
# Successfully read: ../../data/processed/traffic/2018/03-2018_processed.parquet with 40240 rows.
# Successfully read: ../../data/processed/traffic/2018/04-2018_processed.parquet with 38213 rows.
# Successfully read: ../../data/processed/traffic/2018/11-2018_processed.parquet with 34805 rows.
# Successfully read: ../../data/processed/traffic/2018/12-2018_processed.parquet with 38299 rows.
# Successfully read: ../../data/processed/traffic/2018/10-2018_processed.parquet with 36567 rows.
# Combined DataFrame created with 3439270 rows.

# %%
# Define the root directory for processed traffic data
root_dir = '../../data/raw/meteo'

# List to hold DataFrames
dataframes = []

# Iterate through all folders in the root directory
for folder_name in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder_name)
    
    # Check if the folder exists and is a directory
    if os.path.isdir(folder_path):
        print(f"Processing folder: {folder_path}")
        
        # Iterate through all files in the folder
        for file_name in os.listdir(folder_path):
            if file_name.endswith('.grib'):  # Ensure it's a GRIB file
                file_path = os.path.join(folder_path, file_name)
                
                # Read the file
                try:                    
                    df = xr.open_dataset(file_path, engine='cfgrib',  backend_kwargs={'indexpath': None})
                    print(f"Successfully read: {file_path} with {len(df)} rows.")
                    
                    df = df.to_dataframe().reset_index()  # Reset index if needed
                    df = df[df['d2m'].notna()]
                    
                    # Append the DataFrame to the list
                    dataframes.append(df)
                    
                except Exception as e:
                    print(f"Error reading file {file_name}: {e}")

# Concatenate all DataFrames into one
if dataframes:  # Check if the list is not empty
    df_meteo = pd.concat(dataframes, ignore_index=True)
    print(f"Combined DataFrame created with {len(df_meteo)} rows.")
# Out:
# Processing folder: ../../data/raw/meteo/2013
# Successfully read: ../../data/raw/meteo/2013/62bc958b7dfd5f0fd66790535255fdcc.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2013/ffa3eb01f41b6b867176ab7d6c86c36c.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2013/b7c4931dbcd0dc31c51479f26fc69edf.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2013/eee6c89231dec25508bea7cdf1cbf740.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2013/ddadcac45ee7083336adc489c0f1f01f.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2013/1360c89e22b9804a0721de5cb09a2b64.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2013/e215fff01bb60bb2e69e7fd29eef3231.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2013/c3e08645e5b5a7e6112b1312ca3c96d5.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2013/4b18f4ae5616f7e8f4f335741738e89d.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2013/1c4334f2220f5b65d61a35db9cbdf362.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2013/29a9e5c1403dcef73cfbe958232bdba4.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2013/5c6426ce5cbb9fcfc066181fb192ea06.grib with 8 rows.
# Processing folder: ../../data/raw/meteo/2014
# Successfully read: ../../data/raw/meteo/2014/1a627563014be879f7f510425e244f33.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2014/8cd88bde0b008be8bd98e8fa2c3deee.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2014/a19f16a070e81cc8def9f81922403cda.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2014/7ed2da74683343198ed27ff2533761d0.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2014/34c20474d55ddba0a1bb60086f1c95a9.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2014/8e0cf1a7ced05fbc659e32c596cb8960.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2014/8a58e6b430cca834856bf469bdd43a25.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2014/1a08e7e7f58c416896d03901b5f205ea.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2014/df03a19546cdf0298a66c305e49bf775.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2014/a7f7bca08b0ac190f7d576184c8640dd.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2014/53bff0063d2cc1c9bcbbea42e539e8ab.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2014/60f060b0ced797c44d64543a7d9729b2.grib with 8 rows.
# Processing folder: ../../data/raw/meteo/2022
# Successfully read: ../../data/raw/meteo/2022/4e143763b6ddd90830b1b2e53ae3d7a5.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2022/84bbb1de389f549dc6756798501cdca5.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2022/93003d3f27f9fd461aad3ee6e8f7bce0.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2022/e3aa8ebebab5e5eca9010c191fca712.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2022/41df651812e856531f6592e080a66fce.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2022/d9331ddced57882f0d634e4db7abc227.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2022/b3fcc9fe6bc5bd11659b6ba730d19df4.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2022/773f78fa31108dc1bc9242648ce689bd.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2022/b81359a8caf89dcca96e37ff9c93a920.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2022/17d2a65169a31294a6845abb2e3382f6.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2022/7c1318d1d4190de9f3c17e87bde87b29.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2022/5cd58089e942b6663221c4becc02bc2d.grib with 8 rows.
# Processing folder: ../../data/raw/meteo/2024
# Successfully read: ../../data/raw/meteo/2024/93d25982fecb3d45bcff50075ff8bbf2.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2024/a6420429e3e401f6e3ec8f4e72706d4c.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2024/ddaa386b2045e14fe40c23c3254c007b.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2024/2fa0be3cc9df209cd2163144d772fe6e.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2024/87809a191145b10ec6138e442117b5bd.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2024/160596db57955e5817c858a1c80af06b.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2024/12fe350085815bf9c0e14c1705cc590d.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2024/9d93705940aa2fdd3c681fe2849207e4.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2024/4e02a50d5d704fd0461a2e05a89ae265.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2024/695fc8e3fe9eafd2e8831ccc31e40d8d.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2024/a2a31b7e501310bdca5749a19ca612bd.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2024/b2059fbc1784801cf42da7f03fa7e53f.grib with 8 rows.
# Processing folder: ../../data/raw/meteo/2023
# Successfully read: ../../data/raw/meteo/2023/bc7e2caa039d16167fade8b3d4a40aed.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2023/9dbae119896ff49cf20a8baa2351f63c.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2023/9d93457287c68cc526f0e3a4bb7d359e.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2023/2ecb2110facfc276f9c60ffe78c50341.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2023/f11117ec7108e46dc30f615ab787a8d9.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2023/394ff68048e0419c0757a112bff0fd91.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2023/8af2e911e4757d3b71e0f77dd1928ed5.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2023/41dcd1f41a4bae0a49acfd1d2010bb1e.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2023/6a88589e591606605242c07f99c66312.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2023/167f2932fb4e7bf97b9d2b8f1bdeb8c0.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2023/10da73c9dc40da985911f6a7af7cbd00.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2023/97b5ccbcaec5afe405fbb7b096449912.grib with 8 rows.
# Processing folder: ../../data/raw/meteo/2015
# Successfully read: ../../data/raw/meteo/2015/1453b1c8002cd36224e6b74e97cdeaae.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2015/486668a2d9915efaaca6a7d11c9bbe19.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2015/245a75ef5f911d7b3cb2f0605b3f7d9.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2015/d4c42f12d02b62e75073fd2899e85fd7.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2015/411d7c4e5cd297914bff24605a7a12da.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2015/93ad06f6f3429baa0da3dd5dbee76860.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2015/9b4539393150baa08f9908f70738a7c4.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2015/bffcee4b3c065c6f16a125a7c0506d8a.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2015/4c56ef223366034b802b4c4c3974e4db.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2015/394a25e5738ecf867732c11a08087cfe.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2015/cfb5f72366728be4790e5ba31b79e84.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2015/2d5a69d1d90864b7512bc80e8c936320.grib with 8 rows.
# Processing folder: ../../data/raw/meteo/2017
# Successfully read: ../../data/raw/meteo/2017/3fb2370c8dbf6dd86efcd12522fa0a5e.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2017/a48beea99c083387a07c291ad74beae8.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2017/6da2cc9c51364dd864421ef203cc1887.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2017/6988f76abcbda9f7f31d346804e9e027.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2017/c95182d275184ef579422201d99295d1.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2017/4207110654e16b08a17266d41218fe90.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2017/c113ac744b48f456071e5374fda3b765.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2017/932c07740ac1b1af28f34676700cd7fb.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2017/38097e1fbeca94d0958e99d6986c07c3.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2017/79ecafe16308be23ce28238167f76401.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2017/f68008a91c8eff718fcd5f9d10bb07e1.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2017/11861aa8002f0fc23e63db4c6d7c783b.grib with 8 rows.
# Processing folder: ../../data/raw/meteo/2019
# Successfully read: ../../data/raw/meteo/2019/be05ea14c1ccc0fb74408c661342e2fc.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2019/fc990df9a86f354caa1cc85c9501dc35.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2019/777ad6591a54596dc819b98e6887f055.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2019/ea1ae8bfc5e8b3418ab4191e2d113482.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2019/afa5f18419bd6ca1fc6690ebf75b1c25.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2019/81b085a5ed39146d7f5d23474bb260d7.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2019/ed9311c01dac40aabc91fb3864a8abce.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2019/d0cf0def73206066fdd2a4b9d7ec14e.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2019/9659cf7078ec80fcd4ec3d7cfe0b780a.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2019/796f9d461098e26b4338297ba1a2fcfc.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2019/e24e1b8f9ca54f55dd9ed828a221d806.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2019/3567d9dce41be0232f7ec3f6b05e0710.grib with 8 rows.
# Processing folder: ../../data/raw/meteo/2021
# Successfully read: ../../data/raw/meteo/2021/dcc3436662f764237232da1272c9bd96.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2021/7913e38c55da0a692442b2372b655f7e.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2021/7f747ffcf9e635bac32d7a326c53c768.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2021/21f79b8df25ed821b649933c4ec3a372.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2021/2871c94598d2ad63aa702c4ae63f1996.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2021/c8bf10d7b8133ea43e23f5e48992fbdd.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2021/b269cec9bf1cd0101a525d39e64c5c68.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2021/28981aed8cab88c55759d77a7a6be93c.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2021/2fb86115d64a695f29d63d3b6125fdf3.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2021/f8a3a85380ff9d9ceafc88d7efc5aadb.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2021/2c9d7f98e3744057b4160572e4c0faa9.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2021/ba60bb935c9bb2cee88fcccf3ba529bb.grib with 8 rows.
# Processing folder: ../../data/raw/meteo/2020
# Successfully read: ../../data/raw/meteo/2020/9b4658d92afc8730741f6f77459bf0be.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2020/d328f5a2ba7ac698ab8ff2a22457c78d.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2020/6247fc6f6e2d02317e69b09d1c9d1a43.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2020/9a9340907803d298ffeef43715abed65.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2020/e728cdd3bacceef26751422c367fc95b.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2020/106adb151b842aa94e021cac99fda669.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2020/22660c92123c653c8e19ce16e3e5e0e2.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2020/31168da80afe7e03be16154d8b7ba723.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2020/d32d30b2958c57a4712fc19cb5c8ab36.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2020/5fa2d724ef167704e88c405bffefc1f9.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2020/4bb2aa59c8825f75afb8e9edab08e336.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2020/53529b8be8c27d847b6c93b404775f10.grib with 8 rows.
# Processing folder: ../../data/raw/meteo/2018
# Successfully read: ../../data/raw/meteo/2018/e99341ff3b7b94cae8e3ecd140fdd177.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2018/5e57992aac2ac56b7162ae01d706101c.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2018/979398cb4826898b688f868f8f6df5b.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2018/6d41aa349ea12967aa10013f34ffc380.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2018/3626a5f630ed0e9abd392f0052295ec8.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2018/53007aea49134b417d72c70d96447ae5.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2018/495908a0213127247b17bf04990180f4.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2018/884cc40e96d15c88c1e35ae19ab85f77.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2018/64d6bf7ab4452798270cf18dc39bc54b.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2018/646c1c43004891a3c55ed0ed2661f750.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2018/8c6966e697d2fdb22f4aa9d708bd7c7e.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2018/a86e1006af0a7fec8ae40a8484d8975e.grib with 8 rows.
# Processing folder: ../../data/raw/meteo/2016
# Successfully read: ../../data/raw/meteo/2016/fd07c3c5f701385045e1e692e4073464.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2016/97b5ce77caf9b5640ccb0fa9bc7dea7b.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2016/8834983b58e83ecac62e8522270b9f6a.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2016/932dfa7740b33f7d7bf428ee43b84c4d.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2016/6398d98dfd42031c5be351443c4a4ff9.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2016/4a45dbf6367d697e7d6e1c08f0928b01.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2016/9fc7a2e81748716993194c89c18dd0da.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2016/2f8569b1f65f55f38f4fe87f5be42902.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2016/a14c48a07d1b79c5854dd163f81f09f1.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2016/736ea3ffcec41ed07aca80b58c6ac47.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2016/924b6fb3dbe8ec43414f78f388941011.grib with 8 rows.
# Successfully read: ../../data/raw/meteo/2016/4629168a0ad1c42a29e4d9d4ed21ca30.grib with 8 rows.
# Combined DataFrame created with 1031760 rows.

# %% [markdown]
# ## Data Cleaning

# %%
unnecesary_cols = ['PROVINCIA','MUNICIPIO','ESTACION','MAGNITUD','PUNTO_MUESTREO','CODIGO_CORTO','LOCALIZACION','DIRECCION','COD_VIA','COD_TIPO']

df_air = df_air.drop(columns = unnecesary_cols)
df_air.columns = df_air.columns.str.lower()
df_air = df_air.rename(columns = {'codigo':'id_no2'})

# %%
df_air['id_no2'] = df_air['id_no2'].astype(str)
df_mapping['id_trafico'] = df_mapping['id_trafico'].astype(str)
df_mapping['id_no2'] = df_mapping['id_no2'].astype(str)

# %%
df_traffic = df_traffic.rename(columns = {'hora': 'fecha'})

# %%
df_meteo = df_meteo.rename(columns = {'valid_time':'fecha'})
df_meteo = df_meteo.drop(columns = ['time','step','surface'])

# %%
df_meteo.drop(columns = ['number']).to_parquet("all_meteo.parquet", index = False)

# %%
df_meteo = df_meteo.drop(columns = ['number'])

# %%
df_meteo = df_meteo[(df_meteo['latitude'] == 40.7) & (df_meteo['longitude'] == -3.7)]

# %%
# get the unique values of the longitude and latitude of the air quality data

df_air_locations = df_air[['longitud','latitud']].drop_duplicates().reset_index(drop = True)
df_meteo_locations = df_meteo[['longitude','latitude']].drop_duplicates().reset_index(drop = True)

# shown both locations inside a map

# %%
import folium

# Crear un mapa centrado en la ubicación promedio
center_lat = (df_air_locations['latitud'].mean() + df_meteo_locations['latitude'].mean()) / 2
center_lon = (df_air_locations['longitud'].mean() + df_meteo_locations['longitude'].mean()) / 2

# Crear el mapa base
m = folium.Map(location=[center_lat, center_lon], zoom_start=11, 
               tiles='CartoDB positron')

# Añadir marcadores para todas las estaciones de calidad del aire (azul)
for idx, row in df_air_locations.iterrows():
    folium.Marker(
        location=[row['latitud'], row['longitud']],
        popup=f"""
        <b>Estación de aire #{idx}</b><br>
        Latitud: {row['latitud']:.6f}<br>
        Longitud: {row['longitud']:.6f}
        """,
        icon=folium.Icon(color='blue', icon='info-sign'),
        tooltip="Estación de calidad del aire"
    ).add_to(m)

# Añadir marcadores para todas las estaciones meteorológicas (rojo)
for idx, row in df_meteo_locations.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"""
        <b>Estación meteorológica #{idx}</b><br>
        Latitud: {row['latitude']:.6f}<br>
        Longitud: {row['longitude']:.6f}
        """,
        icon=folium.Icon(color='red', icon='cloud'),
        tooltip="Estación meteorológica"
    ).add_to(m)

# Añadir leyenda al mapa
legend_html = '''
<div style="position: fixed; 
     bottom: 50px; right: 50px; width: 220px; height: 90px; 
     border:2px solid grey; z-index:9999; font-size:14px;
     background-color:white; padding: 10px;
     border-radius: 5px;">
     &nbsp; <b>Leyenda</b> <br>
     &nbsp; <i class="fa fa-info-sign fa-2x" style="color:blue"></i>&nbsp; Estaciones de aire<br>
     &nbsp; <i class="fa fa-cloud fa-2x" style="color:red"></i>&nbsp; Estaciones meteorológicas
</div>
'''
m.get_root().html.add_child(folium.Element(legend_html))

# Mostrar el mapa
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81d871ea0cd651a54deebf2ba3339161 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed;
#      bottom: 50px; right: 50px; width: 220px; height: 90px;
#      border:2px solid grey; z-index:9999; font-size:14px;
#      background-color:white; padding: 10px;
#      border-radius: 5px;&quot;&gt;
#      &amp;nbsp; &lt;b&gt;Leyenda&lt;/b&gt; &lt;br&gt;
#      &amp;nbsp; &lt;i class=&quot;fa fa-info-sign fa-2x&quot; style=&quot;color:blue&quot;&gt;&lt;/i&gt;&amp;nbsp; Estaciones de aire&lt;br&gt;
#      &amp;nbsp; &lt;i class=&quot;fa fa-cloud fa-2x&quot; style=&quot;color:red&quot;&gt;&lt;/i&gt;&amp;nbsp; Estaciones meteorológicas
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81d871ea0cd651a54deebf2ba3339161&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81d871ea0cd651a54deebf2ba3339161 = L.map(
#                 &quot;map_81d871ea0cd651a54deebf2ba3339161&quot;,
#                 {
#                     center: [40.467304868750006, -3.6645031500000003],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba38447b0f65910b6930d085160fcfd1 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba38447b0f65910b6930d085160fcfd1.addTo(map_81d871ea0cd651a54deebf2ba3339161);
#
#
#             var marker_089780f514a629b880c755e51814d34c = L.marker(
#                 [40.4238823, -3.7122567],
#                 {
# }
#             ).addTo(map_81d871ea0cd651a54deebf2ba3339161);
#
#
#             var icon_c9905e6d698726cf1444610d2ed44dd0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_089780f514a629b880c755e51814d34c.setIcon(icon_c9905e6d698726cf1444610d2ed44dd0);
#
#
#         var popup_96dc8a6d3fdd3d05072b56d2e30f74b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1a12eb4d57114357aed288f4700ff5e = $(`&lt;div id=&quot;html_b1a12eb4d57114357aed288f4700ff5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Estación de aire #0&lt;/b&gt;&lt;br&gt;         Latitud: 40.423882&lt;br&gt;         Longitud: -3.712257         &lt;/div&gt;`)[0];
#                 popup_96dc8a6d3fdd3d05072b56d2e30f74b4.setContent(html_b1a12eb4d57114357aed288f4700ff5e);
#
#
#
#         marker_089780f514a629b880c755e51814d34c.bindPopup(popup_96dc8a6d3fdd3d05072b56d2e30f74b4)
#         ;
#
#
#
#
#             marker_089780f514a629b880c755e51814d34c.bindTooltip(
#                 `&lt;div&gt;
#                      Estación de calidad del aire
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0884d8f804497693fe9c8d4058cbb35f = L.marker(
#                 [40.4215533, -3.6823158],
#                 {
# }
#             ).addTo(map_81d871ea0cd651a54deebf2ba3339161);
#
#
#             var icon_715f0d2e5ca27a80d6a83f98cea7811f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_0884d8f804497693fe9c8d4058cbb35f.setIcon(icon_715f0d2e5ca27a80d6a83f98cea7811f);
#
#
#         var popup_d1768a7948f6d282ebdb1cf7b26733cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20edf0f7c2c8d529c1739c5a9cef6b85 = $(`&lt;div id=&quot;html_20edf0f7c2c8d529c1739c5a9cef6b85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Estación de aire #1&lt;/b&gt;&lt;br&gt;         Latitud: 40.421553&lt;br&gt;         Longitud: -3.682316         &lt;/div&gt;`)[0];
#                 popup_d1768a7948f6d282ebdb1cf7b26733cd.setContent(html_20edf0f7c2c8d529c1739c5a9cef6b85);
#
#
#
#         marker_0884d8f804497693fe9c8d4058cbb35f.bindPopup(popup_d1768a7948f6d282ebdb1cf7b26733cd)
#         ;
#
#
#
#
#             marker_0884d8f804497693fe9c8d4058cbb35f.bindTooltip(
#                 `&lt;div&gt;
#                      Estación de calidad del aire
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_f2847f27468e84241f8446fc74fc63cd = L.marker(
#                 [40.4514734, -3.6773491],
#                 {
# }

# %% [markdown]
# vamos a quedarnos solo con las estaciones que nos interesan (de momento):
#
# estacion 1
#
# - latitud: 40.5
# - longitud -3.7
#
# TODO: posteriormente podemos sacar datos mas precisos.

# %%
df_meteo = df_meteo[df_meteo['latitude'] == 40.5]
df_meteo = df_meteo[df_meteo['longitude'] == -3.7]

# %%
df_meteo = df_meteo.rename(columns = {'longitude':'longitud_meteo','latitude':'latitud_meteo'})

# %%
df_meteo.to_parquet("meteo_data_one_station.parquet", index = False)

# %% [markdown]
# Joining the data

# %%
df = pd.merge(df_air, df_mapping, how = 'left', left_on='id_no2', right_on='id_no2')
df = pd.merge(df, df_traffic, how = 'inner', left_on=['id_trafico','fecha'], right_on=['id_trafico','fecha'])

# %%
df = pd.merge(df, df_meteo, how = 'inner', left_on=['fecha'], right_on=['fecha'])

# %%
df.to_parquet("no2_with_traffic_and_meteo_one_station.parquet", index=False)

# %% [markdown]
# ## Gestionar outliers y valores faltantes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

# Filtrar para el ID específico
df_sensor = df[df['id_trafico'] == '5084'].copy()

# Asegurarse que las fechas estén en formato datetime
fecha_col = 'fecha'  # Ajusta al nombre real de tu columna de fecha
if not pd.api.types.is_datetime64_any_dtype(df_sensor[fecha_col]):
    df_sensor[fecha_col] = pd.to_datetime(df_sensor[fecha_col])

# Crear un índice de todas las horas que deberían existir
fecha_min = df_sensor[fecha_col].min()
fecha_max = df_sensor[fecha_col].max()
todas_horas = pd.date_range(start=fecha_min, end=fecha_max, freq='H')

# Crear DataFrame con todas las horas
df_completo = pd.DataFrame(index=todas_horas)
df_completo.index.name = 'hora'

# Marcar las horas que existen en los datos originales
df_sensor_hora = df_sensor.set_index(fecha_col)
df_completo['tiene_datos'] = df_completo.index.isin(df_sensor_hora.index).astype(int)

# Calcular estadísticas de completitud
total_horas = len(todas_horas)
horas_con_datos = df_completo['tiene_datos'].sum()
porcentaje_completitud = (horas_con_datos / total_horas) * 100

print(f"Periodo: {fecha_min} a {fecha_max}")
print(f"Total de horas en el periodo: {total_horas}")
print(f"Horas con datos: {horas_con_datos} ({porcentaje_completitud:.2f}%)")
print(f"Horas sin datos: {total_horas - horas_con_datos} ({100-porcentaje_completitud:.2f}%)")

# Visualizar huecos temporales por día y hora
df_completo['fecha'] = df_completo.index.date
df_completo['hora_dia'] = df_completo.index.hour

# Crear matriz para heatmap (días x horas)
matriz_datos = df_completo.pivot_table(
    index=df_completo.index.date, 
    columns='hora_dia', 
    values='tiene_datos', 
    aggfunc='first'
)

# Crear mapa de calor para visualizar presencia/ausencia de datos
plt.figure(figsize=(16, 10))
cmap = LinearSegmentedColormap.from_list('datos', ['#FFFFFF', '#4CAF50'])
ax = sns.heatmap(matriz_datos, cmap=cmap, cbar_kws={'label': 'Datos disponibles'})
ax.set_title(f'Disponibilidad de datos por hora - Sensor {10885}', fontsize=14)
ax.set_xlabel('Hora del día', fontsize=12)
ax.set_ylabel('Fecha', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Periodo: 2018-01-01 00:00:00 a 2024-12-01 00:00:00
# Total de horas en el periodo: 60625
# Horas con datos: 58766 (96.93%)
# Horas sin datos: 1859 (3.07%)
# /var/folders/kc/t6c9n8gj7mbblj0w7sy3ykwm0000gn/T/ipykernel_81765/2613400981.py:18: FutureWarning:
#
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.

# %%
import calplot
import matplotlib.pyplot as plt

# Preparar datos para el calendario
df_completo['fecha'] = pd.to_datetime(df_completo['fecha'])
datos_diarios = df_completo.groupby('fecha')['tiene_datos'].sum()
datos_diarios = datos_diarios / 24 * 100  # Convertir a porcentaje de completitud

# Crear visualización de calendario
plt.figure(figsize=(16, 10))
calplot.calplot(datos_diarios, cmap='YlGn', 
               fillcolor='whitesmoke',
               vmin=0, vmax=100, 
               suptitle=f'Disponibilidad diaria de datos (%) - Sensor {10885}')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/kc/t6c9n8gj7mbblj0w7sy3ykwm0000gn/T/ipykernel_81765/1114446326.py:15: UserWarning:
#
# This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
# Ver cuántos id_trafico están asignados a cada id_no2
resumen = df.groupby('id_no2')['id_trafico'].nunique().reset_index()
resumen.columns = ['id_no2', 'num_sensores_trafico']
print("Número de sensores de tráfico asignados a cada sensor NO2:")
print(resumen.sort_values(by='num_sensores_trafico', ascending=False))

# Identificar sensores NO2 sin sensores de tráfico asignados
sin_trafico = resumen[resumen['num_sensores_trafico'] == 0]['id_no2'].tolist()
if sin_trafico:
    print(f"\nSensores NO2 sin sensores de tráfico asignados: {sin_trafico}")
# Out:
# Número de sensores de tráfico asignados a cada sensor NO2:
#       id_no2  num_sensores_trafico
# 12  28079056                    14
# 0   28079004                    10
# 2   28079011                     8
# 7   28079039                     7
# 5   28079036                     6
# 1   28079008                     5
# 4   28079035                     4
# 10  28079048                     4
# 6   28079038                     3
# 3   28079016                     2
# 8   28079040                     2
# 9   28079047                     2
# 11  28079050                     2

# %%
# Para cada id_no2, quedarse solo con el id_trafico que tenga mas datos y añadir una nueva columna con el numero de datos, el inicio y el fin de los dato

import pandas as pd

# Paso 1: Calcular métricas para cada combinación id_no2 y id_trafico
stats_trafico = df.groupby(['id_no2', 'id_trafico']).agg(
    num_registros=('fecha', 'count'),
    fecha_inicio=('fecha', 'min'),
    fecha_fin=('fecha', 'max')
).reset_index()

# Paso 2: Para cada id_no2, encontrar el id_trafico con más datos
mejor_trafico = stats_trafico.sort_values(['id_no2', 'num_registros'], ascending=[True, False])
mejor_trafico = mejor_trafico.groupby('id_no2').first().reset_index()

# Paso 3: Añadir columnas informativas
mejor_trafico['periodo_dias'] = (mejor_trafico['fecha_fin'] - mejor_trafico['fecha_inicio']).dt.days
mejor_trafico['densidad_datos'] = mejor_trafico['num_registros'] / mejor_trafico['periodo_dias'].clip(lower=1)

# Paso 4: Unir con el DataFrame original para mantener solo las filas con mejores sensores
df_filtrado = pd.merge(
    df,
    mejor_trafico[['id_no2', 'id_trafico']],
    on=['id_no2', 'id_trafico'],
    how='inner'
)

# Paso 5: Añadir las métricas calculadas al DataFrame filtrado
df_final = pd.merge(
    df_filtrado,
    mejor_trafico[['id_no2', 'id_trafico', 'num_registros', 'fecha_inicio', 'fecha_fin', 'periodo_dias', 'densidad_datos']],
    on=['id_no2', 'id_trafico'],
    how='left'
)

# Mostrar resumen del resultado
print(f"DataFrame original: {len(df)} filas, {df['id_no2'].nunique()} sensores NO2, {df['id_trafico'].nunique()} sensores tráfico")
print(f"DataFrame filtrado: {len(df_final)} filas, {df_final['id_no2'].nunique()} sensores NO2, {df_final['id_trafico'].nunique()} sensores tráfico")

# Mostrar información sobre los mejores sensores de tráfico seleccionados
print("\nResumen de mejores sensores de tráfico seleccionados:")
resumen = mejor_trafico[['id_no2', 'id_trafico', 'num_registros', 'periodo_dias']].sort_values('num_registros', ascending=False)
print(resumen.head(20))  # Muestra los 10 primeros

# Opcionalmente, guardar el DataFrame filtrado
# df_final.to_csv('datos_filtrados_mejor_trafico.csv', index=False)
# Out:
# DataFrame original: 3269056 filas, 13 sensores NO2, 69 sensores tráfico
# DataFrame filtrado: 743413 filas, 13 sensores NO2, 13 sensores tráfico
#
# Resumen de mejores sensores de tráfico seleccionados:
#       id_no2 id_trafico  num_registros  periodo_dias
# 11  28079050       5465          59315          2526
# 10  28079048       4461          59291          2526
# 8   28079040       5783          59240          2526
# 9   28079047       4129          58979          2526
# 7   28079039       5422          58813          2526
# 12  28079056       5084          58766          2526
# 6   28079038       4472          58630          2526
# 1   28079008       4022          58618          2526
# 2   28079011       3911          57903          2526
# 5   28079036       6116          57173          2526
# 3   28079016       3791          56290          2526
# 4   28079035       3731          51678          2526
# 0   28079004       4284          48717          2526

# %%
# filtrar el df original para quedarnos con estos id_trafico y los id_no2 que tengan asignados
df_filtered = df[df['id_trafico'].isin(mejor_trafico['id_trafico'])]
df_filtered = df_filtered[df_filtered['id_no2'].isin(mejor_trafico['id_no2'])]

# %%
df_filtered.to_parquet("no2_with_traffic_and_meteo_one_station_filtered_with_best_trafic_id.parquet", index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import streamlit as st
import numpy as np
from datetime import timedelta
import seaborn as sns
import altair as alt
import calplot  # Asegúrate de tener instalada la librería: pip install calplot

@st.cache_data(ttl=3600)
def cargar_datos_trafico_y_meteo():
    """Carga y preprocesa los datos con caché"""
    df = pd.read_parquet('data/more_processed/no2_with_traffic_and_meteo_one_station.parquet')
    df['fecha'] = pd.to_datetime(df['fecha'])
    return df

def analisis_sensores():
    """Función para el análisis comparativo de sensores de tráfico y NO2."""
    
    st.markdown('<div class="sub-header">🚗 Análisis de sensores de tráfico y su relación con NO₂</div>', unsafe_allow_html=True)

    # Información contextual
    with st.expander("ℹ️ Acerca de este análisis", expanded=False):
        st.markdown("""
        <div class="info-box">
        <p>Este panel permite analizar la relación entre los datos de tráfico y los niveles de NO₂ en Madrid.</p>
        </div>
        """, unsafe_allow_html=True)

    # ---- Manejo del estado ----
    if "df_master" not in st.session_state:
        st.session_state.df_master = None

    if st.button("Cargar datos") or st.session_state.df_master is not None:
        if st.session_state.df_master is None:
            with st.spinner('Cargando datos...'):
                try:
                    st.session_state.df_master = cargar_datos_trafico_y_meteo()
                except Exception as e:
                    st.error(f"Error al cargar los datos: {str(e)}")
                    return

        df = st.session_state.df_master

        # --- Controles de configuración ---
        st.markdown('<div class="sub-header">⚙️ Configuración</div>', unsafe_allow_html=True)
        col1, col2 = st.columns([1, 2])
        
        with col1:
            sensores = sorted(df["id_no2"].unique())
            sensor_seleccionado = st.selectbox("Selecciona un sensor de NO₂", sensores, index=0)
            
            # Filtro de fechas
            fecha_min = df["fecha"].min().date()
            fecha_max = df["fecha"].max().date()
            fecha_inicio = st.date_input("Fecha inicial", fecha_min, min_value=fecha_min, max_value=fecha_max, key="sensor_fecha_inicio")
            fecha_fin = st.date_input("Fecha final", fecha_max, min_value=fecha_min, max_value=fecha_max, key="sensor_fecha_fin")
            
            if fecha_inicio > fecha_fin:
                st.error("⚠️ La fecha inicial debe ser anterior a la fecha final")
                fecha_fin = fecha_inicio + timedelta(days=7)
            
            # Granularidad temporal
            granularity = st.radio("Granularidad", ["Horaria", "Diaria", "Semanal", "Mensual"], horizontal=True)
            
            # Variables a analizar
            variables_disponibles = ['intensidad', 'carga', 'ocupacion', 'd2m', 't2m', 'sst', 'ssrd', 'u10', 'v10', 'sp', 'tp']
            variables_disponibles = [var for var in variables_disponibles if var in df.columns]
            variables_seleccionadas = st.multiselect("Selecciona variables a comparar con NO₂", variables_disponibles, default=variables_disponibles)
            
            # Opciones de visualización
            mostrar_correlacion = st.checkbox("Mostrar matriz de correlación", value=True)

            df_filtrado = df[(df["id_no2"] == sensor_seleccionado) & 
                             (df["fecha"].dt.date >= fecha_inicio) & 
                             (df["fecha"].dt.date <= fecha_fin)].copy()

        with col2:
            if df_filtrado.empty:
                st.error("⚠️ No hay datos disponibles para el sensor y rango de fechas seleccionados.")
                return
            
            # Configurar granularidad para análisis de variables (agregación)
            if granularity == "Horaria":
                df_filtrado["time_group"] = df_filtrado["fecha"].dt.floor("H")
            elif granularity == "Diaria":
                df_filtrado["time_group"] = df_filtrado["fecha"].dt.floor("D")
            elif granularity == "Semanal":
                df_filtrado["time_group"] = df_filtrado["fecha"].dt.to_period("W").dt.to_timestamp()
            else:  # Mensual
                df_filtrado["time_group"] = df_filtrado["fecha"].dt.to_period("M").dt.to_timestamp()
            
            if granularity != "Horaria":
                variables_agg = ["no2_value"] + variables_seleccionadas
                df_agregado = df_filtrado.groupby(["time_group"]).agg({var: "mean" for var in variables_agg}).reset_index()
            else:
                df_agregado = df_filtrado

            # --- Sección de visualizaciones ---
            st.markdown('<div class="sub-header">📊 Análisis comparativo de variables</div>', unsafe_allow_html=True)

            if mostrar_correlacion and len(variables_seleccionadas) >= 1:
                st.markdown("### Matriz de correlación")
                corr_data = df_agregado[["no2_value"] + variables_seleccionadas].corr()
                fig, ax = plt.subplots(figsize=(20, 8))
                mask = np.triu(np.ones_like(corr_data, dtype=bool))
                cmap = sns.diverging_palette(230, 20, as_cmap=True)
                sns.heatmap(corr_data, mask=mask, cmap=cmap, annot=True, fmt=".2f", square=True, linewidths=.5, ax=ax)
                plt.title('Correlación entre NO₂ y variables seleccionadas')
                st.pyplot(fig)
            
            # --- Calplot de continuidad de datos ---
            st.markdown('<div class="sub-header">📅 Continuidad de datos (Calplot)</div>', unsafe_allow_html=True)
            # Para la visualización de continuidad, usaremos el dataframe original filtrado a nivel horario.
            # Se asume que los datos deberían estar registrados cada hora.
            fecha_min_sensor = df_filtrado['fecha'].min()
            fecha_max_sensor = df_filtrado['fecha'].max()
            todas_horas = pd.date_range(start=fecha_min_sensor, end=fecha_max_sensor, freq='H')
            
            # Crear DataFrame con todas las horas esperadas
            df_completo = pd.DataFrame(index=todas_horas)
            df_completo.index.name = 'hora'
            df_sensor_hora = df_filtrado.set_index('fecha')
            df_completo['tiene_datos'] = df_completo.index.isin(df_sensor_hora.index).astype(int)
            
            # Cálculo de completitud diaria (porcentaje de horas con datos)
            df_completo['fecha'] = df_completo.index.date
            datos_diarios = df_completo.groupby('fecha')['tiene_datos'].sum()
            datos_diarios = datos_diarios / 24 * 100  # Convertir a porcentaje

            # Crear visualización de calendario
            fig_calplot = plt.figure(figsize=(16, 10))
            calplot.calplot(datos_diarios,
                            cmap='YlGn', 
                            fillcolor='whitesmoke',
                            vmin=0, vmax=100,
                            suptitle=f'Continuidad de datos (%) - Sensor {sensor_seleccionado}')
            plt.tight_layout()
            st.pyplot(fig_calplot)
# Out:
# Periodo: 2018-01-01 00:00:00 a 2024-12-01 00:00:00
# Total de horas en el periodo: 60625
# Horas con datos: 59315 (97.84%)
# Horas sin datos: 1310 (2.16%)
# /var/folders/kc/t6c9n8gj7mbblj0w7sy3ykwm0000gn/T/ipykernel_81765/3775072505.py:18: FutureWarning:
#
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#
# /var/folders/kc/t6c9n8gj7mbblj0w7sy3ykwm0000gn/T/ipykernel_81765/3775072505.py:57: UserWarning:
#
# This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
