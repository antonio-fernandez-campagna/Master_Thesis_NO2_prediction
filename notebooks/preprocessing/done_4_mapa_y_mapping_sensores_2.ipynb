# %%
import pandas as pd

# display all pandas columns
pd.set_option('display.max_columns', None)  # Show all columns

# %% [markdown]
# ## Data import

# %%
df_traffic_data = pd.read_excel('../../data/raw/traffic_sensors_locations/all_sensors.xlsx') 
df_air_quality_and_locations = pd.read_parquet("../../data/processed/air/df_air_quality_and_locations_from_2013.parquet")

# %%
len(df_traffic_data)
# Out:
# 5095

# %%
len(df_traffic_data.drop_duplicates(subset=['longitud', 'latitud']))
# Out:
# 4941

# %%
len(df_air_quality_and_locations)
# Out:
# 2490936

# %%
len(df_air_quality_and_locations.drop_duplicates(subset=["LONGITUD", "LATITUD"]))
# Out:
# 24

# %% [markdown]
# ## Visualization

# %%
import folium

# Remove duplicates for air quality data
df_air_quality_and_locations = df_air_quality_and_locations.drop_duplicates(subset=["LONGITUD", "LATITUD"])

# Remove duplicates for traffic data
df_traffic_data = df_traffic_data.drop_duplicates(subset=['longitud', 'latitud'])  # Assuming 'id' is the identifier for the traffic sensor

# Create a map centered around the average coordinates of the NO2 sensors
map_center = [df_air_quality_and_locations["LATITUD"].mean(), df_air_quality_and_locations["LONGITUD"].mean()]
m = folium.Map(location=map_center, zoom_start=12)

# Add CircleMarkers for NO2 sensors
for _, row in df_air_quality_and_locations.iterrows():
    folium.CircleMarker(
        location=[row["LATITUD"], row["LONGITUD"]],
        radius=8,  # Size of the circle
        color='blue',  # Color for NO2 sensors
        fill=True,
        fill_color='blue',
        fill_opacity=0.9,
        popup=f'Sensor NO2: {row["LONGITUD"]}, {row["LATITUD"]}'
    ).add_to(m)

# Add CircleMarkers for traffic sensors
for _, row in df_traffic_data.iterrows():
    folium.CircleMarker(
        location=[row["latitud"], row["longitud"]],
        radius=2,  # Size of the circle
        color='red',  # Color for traffic sensors
        fill=True,
        fill_color='red',
        fill_opacity=0.1,
        popup=f'Sensor Traffic: {row["id"]}, {row["latitud"]}, {row["longitud"]}'
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_092876a432f6b28ccee9b0509b5d18b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_092876a432f6b28ccee9b0509b5d18b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_092876a432f6b28ccee9b0509b5d18b3 = L.map(
#                 &quot;map_092876a432f6b28ccee9b0509b5d18b3&quot;,
#                 {
#                     center: [40.4346097375, -3.6790062999999997],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24aaf2c5bda2618f54fc808e22c5a334 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_24aaf2c5bda2618f54fc808e22c5a334.addTo(map_092876a432f6b28ccee9b0509b5d18b3);
#
#
#             var circle_marker_d56e7e981ca8274a000b7180d1239d4b = L.circleMarker(
#                 [40.4238823, -3.7122567],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_092876a432f6b28ccee9b0509b5d18b3);
#
#
#         var popup_ae620403c7f103f850153a4709217c1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a70ff04e29ffcb1fb6607c0b61c3ec3e = $(`&lt;div id=&quot;html_a70ff04e29ffcb1fb6607c0b61c3ec3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sensor NO2: -3.7122567, 40.4238823&lt;/div&gt;`)[0];
#                 popup_ae620403c7f103f850153a4709217c1d.setContent(html_a70ff04e29ffcb1fb6607c0b61c3ec3e);
#
#
#
#         circle_marker_d56e7e981ca8274a000b7180d1239d4b.bindPopup(popup_ae620403c7f103f850153a4709217c1d)
#         ;
#
#
#
#
#             var circle_marker_1b40dab5647037cdfe8d73a2918ddfa6 = L.circleMarker(
#                 [40.4215533, -3.6823158],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_092876a432f6b28ccee9b0509b5d18b3);
#
#
#         var popup_a854da58b53ff403d8dda019be6f14c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e2206c28ddfe27699ae98c26946a97d = $(`&lt;div id=&quot;html_1e2206c28ddfe27699ae98c26946a97d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sensor NO2: -3.6823158, 40.4215533&lt;/div&gt;`)[0];
#                 popup_a854da58b53ff403d8dda019be6f14c8.setContent(html_1e2206c28ddfe27699ae98c26946a97d);
#
#
#
#         circle_marker_1b40dab5647037cdfe8d73a2918ddfa6.bindPopup(popup_a854da58b53ff403d8dda019be6f14c8)
#         ;
#
#
#
#
#             var circle_marker_183504000538af8a42afa8f60a3d22ee = L.circleMarker(
#                 [40.4514734, -3.6773491],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_092876a432f6b28ccee9b0509b5d18b3);
#
#
#         var popup_38bfeeae41e50718d15ce01d87a5a5d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32d1ed266785539874738373128c8004 = $(`&lt;div id=&quot;html_32d1ed266785539874738373128c8004&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sensor NO2: -3.6773491, 40.4514734&lt;/div&gt;`)[0];
#                 popup_38bfeeae41e50718d15ce01d87a5a5d8.setContent(html_32d1ed266785539874738373128c8004);
#
#
#
#         circle_marker_183504000538af8a42afa8f60a3d22ee.bindPopup(popup_38bfeeae41e50718d15ce01d87a5a5d8)
#         ;
#
#
#
#
#             var circle_marker_4ad8de8f61af0aa93988877175097715 = L.circleMarker(
#                 [40.4400457, -3.6392422],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArr

# %% [markdown]
# ## Mapear Sensores de NO2 con sensores de Trafico

# %% [markdown]
# `Para ello, como primera iteracion, nos quedaremos solo con los sensores de NO2 que tengan al menos un sensor de trafico en el radio de 200 metros. En el caso de que no haya sensores, no usaremos ese sensor de NO2. En el caso de que haya mas de uno, usaremos los valores intercuartiles.`

# %%
#porque antes he eliminado duplicados...
df_traffic_data = pd.read_excel('../../data/raw/traffic_sensors_locations/all_sensors.xlsx')

# %%
df_air_quality_and_locations = df_air_quality_and_locations[['CODIGO','LATITUD','LONGITUD']]
df_traffic_data = df_traffic_data[['id','latitud','longitud']]

df_air_quality_and_locations = df_air_quality_and_locations.rename(columns={'CODIGO':'id_no2'})
df_traffic_data = df_traffic_data.rename(columns={'id':'id_trafico'})

df_air_quality_and_locations['id_no2'] = df_air_quality_and_locations['id_no2'].astype(str)
df_traffic_data['id_trafico'] = df_traffic_data['id_trafico'].astype(str)

# %%
import pandas as pd
import numpy as np
from scipy.spatial import cKDTree

# ------------------------
# 2. Convertir coordenadas a radianes
# ------------------------
df_air_quality_and_locations[['latitud_rad', 'longitud_rad']] = np.radians(df_air_quality_and_locations[['LATITUD', 'LONGITUD']])
df_traffic_data[['latitud_rad', 'longitud_rad']] = np.radians(df_traffic_data[['latitud', 'longitud']])

# ------------------------
# 3. Construcción del KDTree para búsqueda eficiente
# ------------------------
tree = cKDTree(df_traffic_data[['latitud_rad', 'longitud_rad']])

# Definir radio en radianes (200m ≈ 0.0018 rad)
radio = 200 / 6371000  # Radio de la Tierra en metros

# ------------------------
# 4. Asignación de sensores de tráfico a cada sensor de NO2
# ------------------------
asignaciones = []

for i, row in df_air_quality_and_locations.iterrows():
    idx_cercanos = tree.query_ball_point([row['latitud_rad'], row['longitud_rad']], radio)
    
    for idx in idx_cercanos:
        distance = round(tree.query([row['latitud_rad'], row['longitud_rad']], k=1)[0] * 6371000)  # Convert from radians to meters
        
        asignaciones.append({
            'id_no2': row['id_no2'],
            'id_trafico': df_traffic_data.iloc[idx]['id_trafico'],
            'distance_m': distance,  # New column for distance
            'latitud_no2': row['LATITUD'],  # Latitude from df_air_quality_and_locations
            'longitud_no2': row['LONGITUD'],  # Longitude from df_air_quality_and_locations
            'latitud_trafico': df_traffic_data.iloc[idx]['latitud'],  # Latitude from df_traffic_data
            'longitud_trafico': df_traffic_data.iloc[idx]['longitud']   # Longitude from df_traffic_data
        })

df_mapping_no2_to_traffic = pd.DataFrame(asignaciones)

# %%
df_mapping_no2_to_traffic.to_csv("no2_y_traffic_filtered_by_proximity.csv", index = False)

# %%
df_mapping_no2_to_traffic
# Out:
#       id_no2 id_trafico  distance_m  latitud_no2  longitud_no2  \
# 0   28079004      10647          71    40.423882     -3.712257
# 1   28079004       4333          71    40.423882     -3.712257
# 2   28079004       4313          71    40.423882     -3.712257
# 3   28079004       4285          71    40.423882     -3.712257
# 4   28079004       3732          71    40.423882     -3.712257
# ..       ...        ...         ...          ...           ...
# 66  28079056       6822          24    40.385034     -3.718768
# 67  28079056      10332          24    40.385034     -3.718768
# 68  28079056      10848          24    40.385034     -3.718768
# 69  28079056      10849          24    40.385034     -3.718768
# 70  28079056      11006          24    40.385034     -3.718768
#
#     latitud_trafico  longitud_trafico
# 0           40.4238           -3.7139
# 1           40.4222           -3.7128
# 2           40.4224           -3.7126
# 3           40.4232           -3.7115
# 4           40.4235           -3.7129
# ..              ...               ...
# 66          40.3847           -3.7178
# 67          40.3846           -3.7177
# 68          40.3848           -3.7182
# 69          40.3858           -3.7174
# 70          40.3859           -3.7172
#
# [71 rows x 7 columns]

# %%
import folium
import random

# Create a map centered around the average latitude and longitude
map_center = [df_mapping_no2_to_traffic['latitud_no2'].mean(), df_mapping_no2_to_traffic['longitud_no2'].mean()]
m = folium.Map(location=map_center, zoom_start=12)

# Generate a list of colors for the NO2 sensors
colors = ['blue', 'green', 'orange', 'purple', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'pink', 'lightblue']

# Dictionary to hold the color for each NO2 sensor
no2_colors = {}

# Add markers for NO2 sensors with unique colors
for _, row in df_mapping_no2_to_traffic.iterrows():
    if row['id_no2'] not in no2_colors:
        # Assign a random color from the list
        color = random.choice(colors)
        no2_colors[row['id_no2']] = color
    
    # Add a circle marker for NO2 sensors
    folium.CircleMarker(
        location=[row['latitud_no2'], row['longitud_no2']],
        radius=8,
        color=no2_colors[row['id_no2']],
        fill=True,
        fill_opacity=0.6,
        popup=f"NO2 Sensor ID: {row['id_no2']}",
        tooltip=f"NO2 Sensor ID: {row['id_no2']}"
    ).add_to(m)

# Add markers for Traffic data with the same color as the corresponding NO2 sensor
for _, row in df_mapping_no2_to_traffic.iterrows():
    folium.Marker(
        location=[row['latitud_trafico'], row['longitud_trafico']],
        popup=f"Traffic ID: {row['id_trafico']}, NO2 ID: {row['id_no2']}",
        icon=folium.Icon(color=no2_colors[row['id_no2']], icon='info-sign')  # Use the same color as NO2 sensor
    ).add_to(m)

# Save the map to an HTML file or display it directly
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3ecb4b8ef11220acf19da50feb578c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3ecb4b8ef11220acf19da50feb578c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c3ecb4b8ef11220acf19da50feb578c9 = L.map(
#                 &quot;map_c3ecb4b8ef11220acf19da50feb578c9&quot;,
#                 {
#                     center: [40.423535676056346, -3.6948457563380273],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1260da0a30beba1079414d8985175ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1260da0a30beba1079414d8985175ab.addTo(map_c3ecb4b8ef11220acf19da50feb578c9);
#
#
#             var circle_marker_83f2af91ff264ebda4d44c64db88d386 = L.circleMarker(
#                 [40.4238823, -3.7122567],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c3ecb4b8ef11220acf19da50feb578c9);
#
#
#         var popup_b16060561edf6a5071246bac6ace0b63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbe940e585add347d820f9aaf07cda4b = $(`&lt;div id=&quot;html_bbe940e585add347d820f9aaf07cda4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NO2 Sensor ID: 28079004&lt;/div&gt;`)[0];
#                 popup_b16060561edf6a5071246bac6ace0b63.setContent(html_bbe940e585add347d820f9aaf07cda4b);
#
#
#
#         circle_marker_83f2af91ff264ebda4d44c64db88d386.bindPopup(popup_b16060561edf6a5071246bac6ace0b63)
#         ;
#
#
#
#
#             circle_marker_83f2af91ff264ebda4d44c64db88d386.bindTooltip(
#                 `&lt;div&gt;
#                      NO2 Sensor ID: 28079004
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_c86d6b9310c0cdedb64ba2bd8688a829 = L.circleMarker(
#                 [40.4238823, -3.7122567],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c3ecb4b8ef11220acf19da50feb578c9);
#
#
#         var popup_e760f63e7ebe11bc13f0f30bedf8d7bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_872446c9cdd02d9bb8c6bc9cbb166ebe = $(`&lt;div id=&quot;html_872446c9cdd02d9bb8c6bc9cbb166ebe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NO2 Sensor ID: 28079004&lt;/div&gt;`)[0];
#                 popup_e760f63e7ebe11bc13f0f30bedf8d7bc.setContent(html_872446c9cdd02d9bb8c6bc9cbb166ebe);
#
#
#
#         circle_marker_c86d6b9310c0cdedb64ba2bd8688a829.bindPopup(popup_e760f63e7ebe11bc13f0f30bedf8d7bc)
#         ;
#
#
#
#
#             circle_marker_c86d6b9310c0cdedb64ba2bd8688a829.bindTooltip(
#                 `&lt;div&gt;
#                      NO2 Sensor ID: 28079004
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_727cbf1c556062783b98106da8b37248 = L.circleMarker(
#                 [40.4238823, -3.7122567],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c3ecb4b8ef11220acf19da50feb578c9);
#
#
#         var popup_50a85a098ae5127ab3308cb3d50e898b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b833f924f3fb2e44c8fb9c06952dc874 = $(`&lt;div id=&quot;html_b833f924f3fb2e44c8fb9c06952dc874&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NO2 Sensor ID: 28079004&lt;/div&gt;`)[0];
