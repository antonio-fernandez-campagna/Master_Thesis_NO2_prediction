# %%
import pandas as pd

# %%
pd.read_csv("pmed_ubicacion_01-2018.csv", delimiter=";")
# Out:
#         cod_cent    id                                             nombre  \
# 0     04FT74PM01  1006                                         04FT74PM01
# 1     04TL40PM01  6900                                         04TL40PM01
# 2     10NC18PM01  6893                                         10NC18PM01
# 3     10NC76PM01  6891                                         10NC76PM01
# 4     10XC82PM01  6892                                         10XC82PM01
# ...          ...   ...                                                ...
# 4067       83005  5234    Arboleda - Arboleda-Ctra, Villaverde a Vallecas
# 4068       17031  3565        Ferraz S-N - Buen Suceso-Marques de Urquijo
# 4069       21025  4447  Gral, Martínez Campos, 36 O-E - Zurbano-Miguel...
# 4070       22011  9965  Agustin de Betancourt S-N - Maria de Guzmán-Ma...
# 4071       07005  3607  (AFOROS) Francisco Silvela N-S - Maldonado-Jua...
#
#      tipo_elem                 x                 y
# ...

# %%
pd.read_excel("pmed_ubicacion_04-2018.xlsx")
# Out:
#      cod_cent     id                                             nombre  \
# 0     PM22901   6771                                            PM22901
# 1     PM22971   3494                                            PM22971
# 2     PM23071   6773                                            PM23071
# 3     PM23181   6776                                            PM23181
# 4     PM23187   6931                                            PM23187
# ...       ...    ...                                                ...
# 4096    21002   4427  Gral, Martinez Campos E-O - Fdez,de la Hoz-Mod...
# 4097    42045  10278  AV, CARDENAL HERRERA, 282 ORIA E-O(ANGELITA CA...
# 4098    42047   3712                     TÁCTICO - PICO BALAITUS, 1 N-S
# 4099    42049   3713  La Masó, 80 N-S(La Masó-Av, Cardenal Herrera O...
# 4100    49012   5045   (AFOROS) GRAL, RICARDOS E-O(GAVIOTA-FCO, GARCIA)
#
#      tipo_elem              x             y
# 0          M30  439800.141177  4.481377e+06
# ...
